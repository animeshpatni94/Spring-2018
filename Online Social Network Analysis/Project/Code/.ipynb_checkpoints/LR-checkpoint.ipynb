# %%
from collections import Counter
import matplotlib.pyplot as plt
import networkx as nx
import re
import io
import math
import numpy as np
import pandas as pd
import sys
import time
import nltk as nll
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.sentiment import vader
import csv
from TwitterAPI import TwitterAPI
from sklearn import linear_model
from sklearn.feature_extraction.text import CountVectorizer
import statsmodels.api as sm
from sklearn.cross_validation import train_test_split
# Out:
# C:\Users\Alex\Anaconda3\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
# C:\Users\Alex\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# C:\Users\Alex\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
tweets = pd.read_csv('Trainer.csv',header=0)

# %%
print("File contains %d tweets" % len(tweets))
newTweets = tweets.dropna(axis=0, how='all')
newTweets
# Out:
# File contains 71520 tweets
#               name            id              date  \
# 1      BarackObama  9.670000e+17  22-02-2018 16:00
# 3      BarackObama  9.660000e+17  21-02-2018 16:33
# 5      BarackObama  9.640000e+17  15-02-2018 17:12
# 7      BarackObama  9.640000e+17  14-02-2018 16:25
# 9      BarackObama  9.640000e+17  14-02-2018 16:24
# 11     BarackObama  9.530000e+17  15-01-2018 14:46
# 13     BarackObama  9.470000e+17  29-12-2017 16:11
# 15     BarackObama  9.470000e+17  29-12-2017 16:10
# 17     BarackObama  9.470000e+17  29-12-2017 16:10
# 19     BarackObama  9.470000e+17  29-12-2017 16:09
# 21     BarackObama  9.470000e+17  29-12-2017 16:09
# 23     BarackObama  9.460000e+17  27-12-2017 21:02
# 25     BarackObama  9.450000e+17  25-12-2017 16:05
# 27     BarackObama  9.410000e+17  14-12-2017 22:39
# 29     BarackObama  9.410000e+17  13-12-2017 00:17
# 31     BarackObama  9.400000e+17  11-12-2017 20:16
# 33     BarackObama  9.380000e+17  04-12-2017 22:57
# 35     BarackObama  9.350000e+17  27-11-2017 21:13
# 37     BarackObama  9.340000e+17  23-11-2017 14:44
# 39     BarackObama  9.330000e+17  20-11-2017 19:02
# 41     BarackObama  9.290000e+17  11-11-2017 15:13
# 43     BarackObama  9.280000e+17  08-11-2017 13:25
# 45     BarackObama  9.280000e+17  07-11-2017 01:02
# 47     BarackObama  9.270000e+17  06-11-2017 00:51
# 49     BarackObama  9.270000e+17  06-11-2017 00:51
# 51     BarackObama  9.260000e+17  01-11-2017 13:06
# 53     BarackObama  9.260000e+17  01-11-2017 00:56
# 55     BarackObama  9.250000e+17  30-10-2017 21:36
# 57     BarackObama  9.230000e+17  23-10-2017 22:03
# 59     BarackObama  9.220000e+17  22-10-2017 00:02
# ...            ...           ...               ...
# 71461      mtbarra  5.140000e+17  23-09-2014 14:54
# 71463      mtbarra  5.090000e+17  07-09-2014 22:49
# 71465      mtbarra  5.090000e+17  07-09-2014 21:07
# 71467      mtbarra  5.030000e+17  22-08-2014 18:42
# 71469      mtbarra  5.030000e+17  22-08-2014 18:32
# 71471      mtbarra  5.020000e+17  21-08-2014 15:28
# 71473      mtbarra  5.010000e+17  17-08-2014 19:28
# 71475      mtbarra  5.010000e+17  17-08-2014 17:16
# 71477      mtbarra  5.010000e+17  16-08-2014 16:51
# 71479      mtbarra  5.000000e+17  15-08-2014 17:57
# 71481      mtbarra  4.960000e+17  02-08-2014 16:43
# 71483      mtbarra  4.940000e+17  28-07-2014 15:25
# 71485      mtbarra  4.930000e+17  27-07-2014 20:09
# 71487      mtbarra  4.930000e+17  27-07-2014 20:03
# 71489      mtbarra  4.930000e+17  27-07-2014 19:58
# 71491      mtbarra  4.930000e+17  25-07-2014 14:43
# 71493      mtbarra  4.790000e+17  18-06-2014 17:48
# 71495      mtbarra  4.750000e+17  05-06-2014 11:36
# 71497      mtbarra  4.630000e+17  03-05-2014 16:08
# 71499      mtbarra  4.630000e+17  03-05-2014 16:05
# 71501      mtbarra  4.610000e+17  30-04-2014 13:06
# 71503      mtbarra  4.560000e+17  14-04-2014 14:30
# 71505      mtbarra  4.510000e+17  02-04-2014 20:44
# 71507      mtbarra  4.490000e+17  26-03-2014 13:32
# 71509      mtbarra  4.340000e+17  12-02-2014 15:21
# 71511      mtbarra  4.320000e+17  09-02-2014 01:20
# 71513      mtbarra  4.110000e+17  10-12-2013 21:01
# 71515      mtbarra  4.110000e+17  10-12-2013 20:55
# 71517      mtbarra  3.290000e+17  30-04-2013 01:48
# 71519      mtbarra  3.260000e+17  21-04-2013 16:21
#
#                                                     text  polarity   retweet  \
# 1      b'Young people have helped lead all our great ...       4.0  421736.0
# 3      b'Billy Graham was a humble servant who prayed...       4.0   34176.0
# 5      b'We are grieving with Parkland. But we are no...       4.0  382286.0
# 7      b'Happy Valentine\xe2\x80\x99s Day, @MichelleO...       4.0  245433.0
# 9      b'RT @MichelleObama: Happy #ValentinesDay to m...       4.0   26638.0
# 11     b'Dr. King was 26 when the Montgomery bus boyc...      -4.0  377930.0
# 13     b'All across America people chose to get invol...       0.0  116372.0
# 15     b'Ten-year-old Jahkil Jackson is on a mission ...       4.0   49331.0
# 17     b'Chris Long gave his paychecks from the first...       4.0   67687.0
# 19     b'Kat Creech, a wedding planner in Houston, tu...       0.0   23917.0
# 21     b'As we count down to the new year, we get to ...      -4.0  179111.0
# 23     b'RT @MBK_Alliance: I am my Brother\xe2\x80\x9...       4.0    7037.0
# 25     b'On behalf of the Obama family, Merry Christm...       4.0  255016.0
# 27     b"There's no better time than the holiday seas...       4.0   60298.0
# 29     b'Happy Hanukkah, everybody, from the Obama fa...       4.0   85653.0
# 31     b'Just got off a call to thank folks who are w...       4.0   87769.0
# 33     b'RT @ObamaFoundation: Watch: We hosted a Town...       4.0    6661.0
# 35     b'Michelle and I are delighted to congratulate...       4.0  115842.0
# 37     b'From the Obama family to yours, we wish you ...       4.0  216015.0
# 39     b'ME:  Joe, about halfway through the speech, ...       4.0  507514.0
# 41     b'RT @ObamaFoundation: Today, we honor those w...       0.0    8908.0
# 43     b'This is what happens when the people vote. C...       0.0   73624.0
# 45     b'Every election matters - those who show up d...       0.0   58426.0
# 47     b'May God also grant all of us the wisdom to a...       4.0  117826.0
# 49     b'We grieve with all the families in Sutherlan...       0.0   97149.0
# 51     b'Starting today, you can sign up for 2018 hea...       0.0  137243.0
# 53     b"Michelle and I are thinking of the victims o...       4.0  103901.0
# 55     b'Hello, #ObamaSummit! Thrilled to host civic ...       4.0   21590.0
# 57     b'I\xe2\x80\x99ll let you and @ladygaga handle...      -4.0   54886.0
# 59      504408.0       0.0
# ...          ...       ...
# 71461       29.0       NaN
# 71463       35.0       NaN
# 71465       36.0       NaN
# 71467       37.0       NaN
# 71469       98.0       NaN
# 71471       19.0       NaN
# 71473       22.0       NaN
# 71475       94.0       NaN
# 71477       79.0       NaN
# 71479       49.0       NaN
# 71481       43.0       NaN
# 71483       46.0       NaN
# 71485      172.0       NaN
# 71487       29.0       NaN
# 71489       27.0       NaN
# 71491       31.0       NaN
# 71493       67.0       NaN
# 71495       36.0       NaN
# 71497       92.0       NaN
# 71499       54.0       NaN
# 71501       76.0       NaN
# 71503       49.0       NaN
# 71505      100.0       NaN
# 71507       53.0       NaN
# 71509       43.0       NaN
# 71511       37.0       NaN
# 71513      105.0       NaN
# 71515      120.0       NaN
# 71517        0.0       NaN
# 71519        9.0       NaN
#
# [35760 rows x 8 columns]

# %%
#This code populates the vader sentiments for the above table
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

negList = []
neuList = []
posList = []
compList = []

sentences = newTweets['text']
ana = SentimentIntensityAnalyzer()
for sentence in sentences:
    sentiment = ana.polarity_scores(sentence)
    negList.append(sentiment['neg'])
    neuList.append(sentiment['neu'])
    posList.append(sentiment['pos'])
    compList.append(sentiment['compound'])
    
newTweets['neg_vader'] = negList
newTweets['neu_vader'] = neuList
newTweets['pos_vader'] = posList
newTweets['comp_vader'] = compList
# Out:
# C:\Users\Alex\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Alex\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Alex\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Alex\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
newTweets.head()
# Out:
#           name            id              date  \
# 1  BarackObama  9.670000e+17  22-02-2018 16:00
# 3  BarackObama  9.660000e+17  21-02-2018 16:33
# 5  BarackObama  9.640000e+17  15-02-2018 17:12
# 7  BarackObama  9.640000e+17  14-02-2018 16:25
# 9  BarackObama  9.640000e+17  14-02-2018 16:24
#
#                                                 text  polarity   retweet  \
# 1  b'Young people have helped lead all our great ...       4.0  421736.0
# 3  b'Billy Graham was a humble servant who prayed...       4.0   34176.0
# 5  b'We are grieving with Parkland. But we are no...       4.0  382286.0
# 7  b'Happy Valentine\xe2\x80\x99s Day, @MichelleO...       4.0  245433.0
# 9  b'RT @MichelleObama: Happy #ValentinesDay to m...       4.0   26638.0
#
#          fav  Animesh   neg_vader  neu_vader  pos_vader  comp_vader
# 1  1510414.0       4.0      0.000      0.580      0.420      0.9192
# 3   242795.0       4.0      0.000      0.676      0.324      0.8442
# 5  1316824.0       4.0      0.201      0.711      0.089     -0.5106
# 7  1514759.0       4.0      0.000      0.805      0.195      0.4404
# 9        0.0       4.0      0.000      0.697      0.303      0.8126

# %%
print("File contains %d tweets" % len(tweets))
tweets.retweet.mean(), tweets.fav.mean()
# Out:
# File contains 71520 tweets
# (6156.4680089485455, 9956.337527964206)

# %%
jkOverall = newTweets.loc[(newTweets['name'] == 'jk_rowling')]
print(jkOverall['retweet'].min())
posVader = jkOverall.loc[(jkOverall['comp_vader'] == 0.0)]
posVader['retweet'].min(), posVader['retweet'].max(), posVader['retweet'].mean()
# Out:
# 1.0
# (1.0, 406775.0, 7221.271134020619)

# %%
plt.scatter(tweets.polarity,tweets.retweet)
axes = plt.gca()
plt.xlabel('Polarity')
plt.ylabel('# of retweets')
plt.rcParams['figure.figsize'] = 10,20
plt.show()

# %%
plt.scatter(newTweets['comp_vader'],newTweets['retweet'])
axes = plt.gca()
plt.xlabel('Polarity')
plt.ylabel('# of retweets')
plt.rcParams['figure.figsize'] = 5,5
plt.show()

# %%
c = Counter(newTweets['comp_vader'])
rt = Counter(newTweets['retweet'])
print("Total # of values is: %d " % len(newTweets['comp_vader']))
print("There are %d polarity values in c" % len(c))
print("There are %d that are 0.0 in c" % c[0.0])

print("-----------------------------------------")
print("There are %d count values in rt" % len(rt))
print("There are %d that are 0 in rt" % rt[0])

print([r for r in rt if r > 1500000])
# Out:
# Total # of values is: 35760
# There are 2658 polarity values in c
# There are 14726 that are 0.0 in c
# -----------------------------------------
# There are 10050 count values in rt
# There are 2709 that are 0 in rt
# [1716883.0]

# %%
'''This block starts logistic regression for Text v. Polarity (TextBlob)'''
y = np.array(newTweets['polarity'])
vectorizer = CountVectorizer(min_df=1, ngram_range=(1,1))

X = vectorizer.fit_transform(newTweets['text'])
vocab = np.array(vectorizer.get_feature_names())

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
lm = linear_model.LogisticRegression()
result = lm.fit(X_train,y_train)
predicted = lm.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(lm.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.90

# %%
#This is to check for overfitting, .686 to .76 is pretty bad
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
tempList = {}
for i in range(2,11):
    kfold = model_selection.KFold(n_splits=i, random_state=None)
    results = model_selection.cross_val_score(lm, X_train, y_train, cv=kfold, scoring='accuracy')
    tempList[i] = results.mean()
#kfold = model_selection.KFold(n_splits=10, random_state=None)
#results = model_selection.cross_val_score(lm, X_train, y_train, cv=kfold, scoring='accuracy')
#print("10-fold cross validation average accuracy: %.3f" % (results.mean()))

# %%
tempList
plt.scatter(tempList.keys(),tempList.values())
axes = plt.gca()
plt.title('Accuracy v. KFold Splits')
plt.xlabel('KFold splits')
plt.ylabel('Accuracy')
plt.rcParams['figure.figsize'] = 10,10
plt.show()

# %%
#https://apps.timwhitlock.info/emoji/tables/unicode - the xe2, x80, x9f, xf0, xa6, ect.. Are emoji/unicode characters
#Top 10 most frequent terms
#Sum columns:
col_sums = X.sum(axis=0).A1
#Sort sums in descending order, and return the top 10 indices.
top_indices = np.argsort(col_sums)[::-1][:20]
print('top_indices=', top_indices)

#map index->term
top_terms = vocab[top_indices]
#get counts for top 10 terms
top_term_counts = col_sums[top_indices]
#print
[x for x in zip(top_terms, top_term_counts)]
# Out:
# top_indices= [12019 23305 48445 55947 54517 49312 43115 36323 23304  6083 19245 57044
#  24378 55538 55380 55984 25041 36708 25132 53180]
# [('co', 23111),
#  ('https', 16479),
#  ('the', 15748),
#  ('xe2', 15662),
#  ('x80', 14331),
#  ('to', 13337),
#  ('rt', 8063),
#  ('of', 7326),
#  ('http', 6908),
#  ('and', 6796),
#  ('for', 6583),
#  ('you', 6533),
#  ('in', 6490),
#  ('xa6', 6458),
#  ('x9f', 6354),
#  ('xf0', 6313),
#  ('is', 5587),
#  ('on', 4797),
#  ('it', 4563),
#  ('we', 4331)]

# %%
# Top Weighted Features
# Get the learned coefficients for the Positive class.
coef = lm.coef_[2]
# Sort them in descending order.
top_coef_ind = np.argsort(coef)[::-1][:20]
# Get the names of those features.
top_coef_terms = vocab[top_coef_ind]
# Get the weights of those features
top_coef = coef[top_coef_ind]
# Print the top 10.
print('top weighted terms for positive class:')
[x for x in zip(top_coef_terms, top_coef)]
# Out:
# top weighted terms for positive class:
# [('happy', 5.8376632393467798),
#  ('best', 5.6759983501880305),
#  ('lol', 5.4729858734485584),
#  ('great', 5.3834950231359384),
#  ('good', 5.3449008119676087),
#  ('love', 5.1723942065826911),
#  ('more', 5.1685024844474263),
#  ('live', 5.1554672925577361),
#  ('win', 5.0701986050852659),
#  ('favorite', 5.0521596467047951),
#  ('proud', 4.9592711343558502),
#  ('amazing', 4.8967455453175246),
#  ('awesome', 4.8863415771362089),
#  ('excited', 4.8476449624756786),
#  ('new', 4.7046906488921065),
#  ('thanks', 4.6837166919861657),
#  ('ready', 4.6441350511691981),
#  ('own', 4.629710497945398),
#  ('better', 4.5921823407278533),
#  ('first', 4.5760177140254124)]

# %%
y = np.array(newTweets['retweet'])
vectorizer = CountVectorizer(min_df=1, ngram_range=(1,1))

X = np.array(newTweets['polarity'])

# %%
print(y,X)
# Out:
# [  4.21736000e+05   3.41760000e+04   3.82286000e+05 ...,   8.70000000e+01
#    4.60000000e+01   5.00000000e+00] [ 4.  4.  4. ...,  4.  0.  4.]

# %%
spaceTwee = newTweets.loc[(newTweets['name'] == 'johngreen') & (newTweets['retweet'] < 300) & (newTweets['retweet'] > 0) & (newTweets['comp_vader'] != 0)]

# %%
obamaOverall = newTweets.loc[(newTweets['name'] == 'BarackObama')]
obamaNeu_avgrt = newTweets.loc[(newTweets['name'] == 'BarackObama') & (newTweets['polarity'] == 0.0)]
obamaPos_avgrt = newTweets.loc[(newTweets['name'] == 'BarackObama') & (newTweets['polarity'] == 4.0)]
obamaNeg_avgrt = newTweets.loc[(newTweets['name'] == 'BarackObama') & (newTweets['polarity'] == -4.0)]

# %%
obamaOverall['retweet'].mean(),obamaPos_avgrt['retweet'].mean(), obamaNeu_avgrt['retweet'].mean(), obamaNeg_avgrt['retweet'].mean()
# Out:
# (5674.207908557306, 5462.45501285347, 5375.397153024911, 8389.123188405798)

# %%
obamaOverall['fav'].mean(), obamaPos_avgrt['fav'].mean(), obamaNeu_avgrt['fav'].mean(),obamaNeg_avgrt['fav'].mean()
# Out:
# (18760.16496756256, 18740.31555269923, 17197.262633451955, 26828.148550724636)

# %%
print(obamaOverall['retweet'].min())
posVader = obamaOverall.loc[(obamaOverall['comp_vader'] < 1)]
posVader['retweet'].min(), posVader['retweet'].max(), posVader['retweet'].mean()
# Out:
# 140.0
# (140.0, 1716883.0, 5674.207908557306)

# %%
plt.scatter(obamaOverall.comp_vader,obamaOverall.retweet)
axes = plt.gca()
plt.xlabel('Polarity')
plt.ylabel('# of retweets')
plt.rcParams['figure.figsize'] = 5,5
plt.show()

# %%
#FIXME: Need to change tweets['tag'] to a specific user
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
X = np.array(spaceTwee['comp_vader']).reshape(-1,1)
#y = pd.factorize(spaceTwee['retweet'].values)[0].reshape(-1, 1)
y = np.array(spaceTwee['retweet']).reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(
                     X, y, test_size=0.33, random_state=42
)
clf.fit(X_train, y_train) 
print(clf.score(X_test, y_test))
# Out:
# 0.00308910408799

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

def populate_vader_X():
    negList = []
    neuList = []
    posList = []
    compList = []

    sentences = X['text']
    ana = SentimentIntensityAnalyzer()
    for sentence in sentences:
        sentiment = ana.polarity_scores(sentence)
        negList.append(sentiment['neg'])
        neuList.append(sentiment['neu'])
        posList.append(sentiment['pos'])
        compList.append(sentiment['compound'])

    X['neg_vader'] = negList
    X['neu_vader'] = neuList
    X['pos_vader'] = posList
    X['comp_vader'] = compList

# %%
#imports
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
import numpy as np
import csv
#tweets1 = csv.reader(open('MannuallyTag.csv','rt'), delimiter=',', quotechar='|')
#reading data from excel file
#ile = pd.read_csv(".csv",encoding="utf-8")
file = pd.read_excel("obama.xlsx")


newFile = file.loc[(file['fav_count'] != 0) & (file['retweet'] != 0) & (file['retweet'] < 250000)]

#This lowers accuracy, dropping indexes
#newFile = newFile.drop(newFile.index[[128,146,124,129,93,175,182,86,186,118,125,140,160,199,110,138,94,144,104]])

tempF = newFile.loc[(newFile['retweet'] == 470)]
#print(tempF)
#newFile = file
#print(len(newFile))

# lets take X be the feature matrix and Y be the target variable
Y= newFile.retweet
X= newFile.ix[:, newFile.columns != 'retweet']

'''obamaOverall['retweet'].mean()
obamaPos_avgrt['retweet'].mean()
obamaNeu_avgrt['retweet'].mean()
obamaNeg_avgrt['retweet'].mean()'''

X['text_len'] = 0
tempLen = []

for i in X['text']:
    tempLen.append(len(i))
    #X['text_len'] = len(i)
X['text_len'] = tempLen    

#X['text_len'] = newFile['text'])
X['avg_re'] = newFile.retweet.mean()
X['avg_fav'] = newFile.fav_count.mean()

populate_vader_X()
# create a Python list of feature names
feature_cols = ['naïve_bayes','follower','friendscount','avg_re','avg_fav']
print(X.head())

# use the list to select a subset of the original DataFrame
X1 = X[feature_cols]

#splitting the file into train and test (75% rows in train and 25% in test)
X_train, X_test, Y_train, Y_test = train_test_split(X1, Y, random_state=1)

#checking train and test files shape
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
Y.head()
# Out:
# C:\Users\Alex\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#                                 id                date  \
# 1  BarackObama  978000000000000000 2018-03-25 15:34:00
# 3  BarackObama  976000000000000000 2018-03-19 21:48:00
# 4  BarackObama  976000000000000000 2018-03-19 15:10:00
# 5  BarackObama  974000000000000000 2018-03-16 00:22:00
# 6  BarackObama  974000000000000000 2018-03-15 23:16:00
#
#                                                 text  polarity  fav_count  \
# 1  b'Incredible to have a Chicago team in the Fin...         4     223663
# 3  b'Our most important task as a nation is to ma...         4     137598
# 4  b'In Singapore with young people who are advoc...         4     173985
# 5  b'41: I like the competition. And the loyalty ...         0     281448
# 6  b'Congrats to @LoyolaChicago and Sister Jean f...         0     130989
#
#     follower  friendscount       avg_re       avg_fav  tweet_num  naïve_bayes  \
# 1  101652970        623384  3206.061397  11758.993649      15508            0
# 3  101652970        623384  3206.061397  11758.993649      15508            4
# 4  101652970        623384  3206.061397  11758.993649      15508            4
# 5  101652970        623384  3206.061397  11758.993649      15508            0
# 6  101652970        623384  3206.061397  11758.993649      15508           -4
#
#    text_len  neg_vader  neu_vader  pos_vader  comp_vader
# 1       165      0.000      0.901      0.099      0.2714
# 3       165      0.000      0.728      0.272      0.7264
# 4       154      0.000      1.000      0.000      0.0000
# 5        93      0.000      0.647      0.353      0.7184
# 6        95      0.147      0.678      0.175      0.1260
# (2125, 5)
# (2125,)
# (709, 5)
# (709,)
# 1    20178
# 3    27306
# 4    26533
# 5    29941
# 6    13179
# Name: retweet, dtype: int64

# %%
rf = LinearRegression()
rf.fit(X_train,Y_train)

Y_pred = rf.predict(X_test)
print()
#calculating RMSE
print(np.sqrt(mean_squared_error(Y_test, Y_pred)))
print("Accuracy:",rf.score(X_test, Y_test))

print("Actual vs Predicted using Linear Regression")
tempPD = pd.DataFrame({'Predicted Retweet':Y_pred,'Actual Retweets':Y_test})

finTempPD = tempPD
finTempPD['off_by'] = abs(finTempPD['Predicted Retweet'] - finTempPD['Actual Retweets'])

closestVals = finTempPD.loc[(finTempPD['off_by'] < 1500)]
accScore = len(closestVals)/len(finTempPD)
print(len(closestVals), len(finTempPD), accScore)

plt.scatter(Y_pred,Y_test)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.rcParams['figure.figsize'] = 5,5
plt.show()
# Out:
# 10049.1377339
# Accuracy: 0.0194398178853
# Actual vs Predicted using Linear Regression
# 274 709 0.38645980253878703

# %%
#Random Forest on Training Data and Checking on Test Data
rf = RandomForestRegressor()
rf.fit(X_train,Y_train)

Y_pred = rf.predict(X_test)
print()
#calculating RMSE
print(np.sqrt(mean_squared_error(Y_test, Y_pred)))
print("Accuracy:",rf.score(X_test, Y_test))

print("Actual vs Predicted using Random Forest")
tempPD2 = pd.DataFrame({'Predicted Retweet':Y_pred,'Actual Retweets':Y_test})

#finTempPD = tempPD.loc[(tempPD['Predicted Retweet'] < 40000) & (tempPD['Actual Retweets'] < 10000)]
finTempPD = tempPD2
finTempPD['off_by'] = abs(finTempPD['Predicted Retweet'] - finTempPD['Actual Retweets'])

listOfRanges = [250,500,750,1000,1250,1500,1750,2000]
holdVals = {}

for i in listOfRanges:
    closestVals = finTempPD.loc[(finTempPD['off_by'] < i)]
    accScore = len(closestVals)/len(finTempPD)
    holdVals[i] = accScore
    

    
print(holdVals)

plt.scatter(holdVals.keys(),holdVals.values())
plt.title('Within Range v. Total Range')
plt.xlabel('Range of Retweet')
plt.ylabel('Percentage within Range')
plt.rcParams['figure.figsize'] = 5,5
plt.show()

    
closestVals = finTempPD.loc[(finTempPD['off_by'] < 500)]
accScore = len(closestVals)/len(finTempPD)
print(len(closestVals), len(finTempPD), accScore)
#364 within 1000

#714 total
print(closestVals)

#print("Accuracy 2: ", rf.score(X_test, finTempPD['Actual Retweets']))

plt.scatter(Y_pred,Y_test)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt
axes = plt.gca()
plt.xlabel('Polarity')
plt.ylabel('# of retweets')
plt.rcParams['figure.figsize'] = 10,20
plt.show()

# %%
spaceTwee = tweets.loc[(tweets['name'] == 'johngreen') & (tweets['retweet'] > 1000)]

# %%
print(len(spaceTwee))
# Out:
# 170

# %%
newTwee = tweets.loc[(tweets['name'] == 'johngreen') & (tweets['retweet'] == 0)]

# %%
print(len(newTwee))
# Out:
# 773

# %%
posGreen = newTweets.loc[(newTweets['name'] == 'johngreen') & (newTweets['comp_vader'] > 0)]
negGreen = newTweets.loc[(newTweets['name'] == 'johngreen') & (newTweets['comp_vader'] < 0)]

# %%
print(negGreen, posGreen)
# Out:
#             name            id              date  \
# 44977  johngreen  9.630000e+17  13-02-2018 12:57
# 44993  johngreen  9.620000e+17  08-02-2018 15:14
# 45019  johngreen  9.610000e+17  07-02-2018 16:02
# 45039  johngreen  9.590000e+17  02-02-2018 18:15
# 45063  johngreen  9.590000e+17  31-01-2018 18:51
# 45077  johngreen  9.590000e+17  31-01-2018 00:40
# 45099  johngreen  9.570000e+17  25-01-2018 17:38
# 45101  johngreen  9.570000e+17  25-01-2018 17:37
# 45111  johngreen  9.560000e+17  23-01-2018 23:04
# 45125  johngreen  9.540000e+17  19-01-2018 22:05
# 45131  johngreen  9.540000e+17  19-01-2018 17:38
# 45165  johngreen  9.520000e+17  12-01-2018 13:02
# 45179  johngreen  9.510000e+17  10-01-2018 17:45
# 45181  johngreen  9.510000e+17  10-01-2018 17:41
# 45183  johngreen  9.510000e+17  10-01-2018 17:35
# 45193  johngreen  9.500000e+17  08-01-2018 17:28
# 45209  johngreen  9.470000e+17  29-12-2017 23:50
# 45215  johngreen  9.470000e+17  29-12-2017 18:43
# 45233  johngreen  9.460000e+17  26-12-2017 04:29
# 45241  johngreen  9.450000e+17  24-12-2017 14:22
# 45247  johngreen  9.450000e+17  23-12-2017 20:59
# 45249  johngreen  9.450000e+17  23-12-2017 18:16
# 45253  johngreen  9.440000e+17  23-12-2017 03:45
# 45265  johngreen  9.440000e+17  22-12-2017 17:29
# 45267  johngreen  9.440000e+17  22-12-2017 14:34
# 45269  johngreen  9.440000e+17  22-12-2017 13:57
# 45319  johngreen  9.430000e+17  19-12-2017 19:58
# 45367  johngreen  9.420000e+17  17-12-2017 01:32
# 45431  johngreen  9.420000e+17  16-12-2017 01:56
# 45507  johngreen  9.410000e+17  14-12-2017 18:17
# ...          ...           ...               ...
# 50717  johngreen  8.080000e+17  11-12-2016 00:22
# 50751  johngreen  8.080000e+17  10-12-2016 15:44
# 50765  johngreen  8.080000e+17  10-12-2016 15:00
# 50767  johngreen  8.080000e+17  10-12-2016 14:57
# 50785  johngreen  8.080000e+17  10-12-2016 14:30
# 50849  johngreen  8.070000e+17  10-12-2016 02:35
# 50851  johngreen  8.070000e+17  10-12-2016 02:29
# 51013  johngreen  8.070000e+17  08-12-2016 23:24
# 51053  johngreen  8.070000e+17  08-12-2016 04:25
# 51127  johngreen  8.060000e+17  06-12-2016 15:59
# 45269  b'How the Rohingya Escaped is gutwrenching, vi...      -4.0    290.0
# 45319  b'And a similar couple earning $1,000,000 rece...       0.0    163.0
# 45367  b'Still adding new perks at https://t.co/rX1Mq...       4.0     18.0
# 45431  b"RT @UpliftTogether: If you're not watching t...       4.0     30.0
# 45507  b'RT @mountain_goats: this is very bad news ht...      -4.0    614.0
# ...                                                  ...       ...      ...
# 50717  b"RT @martha_s: I'm just gonna leave this here...       0.0     27.0
# 50751  b'We just featured a new video about the Flint...       4.0     67.0
# 50765  b'.@MenInBlazers have donated a limited editio...      -4.0     13.0
# 50767  b'RT @coollike: NEW VIDEO! My cat and I record...      -4.0     70.0
# 50785  b"Sorry if you missed @AmazingPhil's drawings ...      -4.0   2920.0
# 50849  b'RT @annamberg1: If you\'re not watching #p4a...      -4.0     73.0
# 50851  b"If you're not watching the #p4a2016 livestre...      -4.0     69.0
# 51013  b"@hankgreen That is the worst idea you've eve...      -4.0     14.0
# 51053  b'@MegMHanna No, with the matching MUCH MUCH M...       4.0      0.0
# 51127  b'RT @MaxCRoser: Everyone now knows the viral ...       0.0    417.0
# 51169  b'@hankgreen Update: I am totally wrong, as pe...      -4.0     10.0
# 51177  b'Vidcon coming to Amsterdam, Melbourne, and A...       0.0     31.0
# 51197  b"@AndRChelsea @cue0882 @VlogBrothersFTW @edit...       0.0      2.0
# 51225  b"@MaxwellMayhew Alas, we do not negotiate int...      -4.0      0.0
# 51241  b"Say goodbye to 2016 with Bruno Moraes' epic ...       4.0    134.0
# 51273  b'@hankgreen @NathanZed I have your password f...       4.0     61.0
# 51275  b'@hankgreen @NathanZed WHY DO YOU HAVE MY PAS...      -4.0     55.0
# 51281  b"Worked just fine in 1930! \n\nWhat's that? \...       4.0   1113.0
# 51285  b'RT @ATLBlackStar: Boy, 8, Hospitalized After...       0.0    996.0
# 51295  b'RT @hankgreen: Time to clear out the warehou...       4.0     49.0
# 51297  b'RT @Mabuckley88: Mike Pence wants emails lim...       4.0    407.0
# 51299  b'RT @hankgreen: Total sea ice right now is no...       4.0   2362.0
# 51313  b'Breaking hiatus to say 3 things: 1. Pizzamas...       0.0     58.0
# 51315  b"RT @lexcanroar: don't tell me @ 16 that I ge...       4.0     28.0
# 51321  b'RT @alexandra88: Viral Fake Election News Ou...      -4.0    186.0
# 51325  b'RT @jelani9: "To be led by a coward is to be...       0.0   1762.0
# 51347  b"RT @DFTBArecords: Let's be honest...2016 was...       4.0    199.0
# 51349  b"RT @yashar: NBC's great Pete Williams chokes...       4.0   1022.0
# 51365  b'@Hermalaa @bearenglish Thanks.*           * ...      -4.0      1.0
# 51379  b'Hannah fills in for @hankgreen on vlogbrothe...      -4.0     79.0
#
#            fav  Animesh   neg_vader  neu_vader  pos_vader  comp_vader
# 44977      0.0       NaN      0.064      0.936      0.000     -0.1280
# 44993     97.0       NaN      0.145      0.855      0.000     -0.2960
# 45019      0.0       NaN      0.311      0.554      0.135     -0.7269
# 45039    555.0       NaN      0.317      0.683      0.000     -0.6331
# 45063      0.0       NaN      0.219      0.619      0.162     -0.2942
# ...                                                  ...       ...      ...
# 51229  b'RT @artassignment: And we have a shirt! With...       4.0    141.0
# 51231  b'RT @DFTBArecords: So many hand signed poster...       4.0     17.0
# 51233  b'@denisonscience Thanks! I can tell you have ...       4.0      0.0
# 51239  b'Or get this "Nerds Like Us" poster, designed...       0.0    252.0
# 51243  b'Everything at https://t.co/jju58OV1dH is 20%...       4.0     54.0
# 51245  b'RT @HCTriage: Shoppers! All our merchandise,...       4.0     12.0
# 51253  b'@rainbowrowell I am glad the books are hand ...       4.0     23.0
# 51255  b"RT @drcathywittman: Ever feel like you're no...      -4.0     40.0
# 51257  b'.@NathanZed has just made the greatest video...       4.0    267.0
# 51267  b'Everything at https://t.co/NzDtAMPyfu is 20%...       4.0     83.0
# 51269  b'RT @starmom16: I am grateful for family &amp...       4.0     17.0
# 51279  b"RT @iSmashFizzle: As an addendum to my comme...       0.0     15.0
# 51289  b'RT @mikeyface: If you need perspective in yo...       4.0     85.0
# 51305  b"RT @TEKSTartist: PIZZAMAS FINAL HOURS! Here'...      -4.0     17.0
# 51307  b'@JustineLavaworm So, so, so intense, Justine...      -4.0      0.0
# 51309  b"I also read THE HATE U GIVE by Angie Thomas,...       4.0    145.0
# 51311  b'2. While not Interneting this week, I read t...      -4.0     64.0
# 51319  b'RT @planetalvina: "Be kind. \nMake art. \nFi...       4.0    390.0
# 51327  b'RT @MTVNews: What\xe2\x80\x99s it like to sp...      -4.0    335.0
# 51331  b'@Mrs_Karrs_Fav @TheCrashCourse Yes! https://...       0.0      0.0
# 51333  b"RT @CarringtonJess: A good thing! It's still...       4.0     13.0
# 51337  b'RT @mabuasaker: As #Mosul Displacement Conti...       0.0     32.0
# 51341  b'RT @LatinoUSA: Welcome to the @NPR family, @...       4.0     44.0
# 51345  b"RT @LogoTV: Throughout #TransWeeks, we'll hi...       4.0    660.0
# 51355  b'"We should be careful / Of each other, we sh...       4.0    257.0
# 51357  b"...to amplify voices that are too often goin...       4.0     47.0
# 51369  b'RT @artassignment: New video! Watch the @gue...       4.0     21.0
# 51371  b'RT @valerie2776: I can personally attest to ...       0.0     18.0
# 51375  b'RT @hankgreen: NerdCon: Nerdfighteria is goi...      -4.0     38.0
# 51377  b'Thanks to the wonderful @harto, whose videos...       4.0     27.0
#
#           fav  Animesh   neg_vader  neu_vader  pos_vader  comp_vader
# 44933     0.0       NaN      0.000      0.576      0.424      0.8516
# 44943     0.0       NaN      0.000      0.909      0.091      0.2960
# 44947  2302.0       NaN      0.000      0.386      0.614      0.7471
# 44953     0.0       NaN      0.117      0.736      0.147      0.1799
# 44955   564.0       NaN      0.000      0.711      0.289      0.7269
# 44957     0.0       NaN      0.000      0.783      0.217      0.5719
# 44965    81.0       NaN      0.000      0.494      0.506      0.9544
# 44967  1553.0       NaN      0.000      0.408      0.592      0.4404
# 44969    62.0       NaN      0.000      0.814      0.186      0.4926
# 44971   357.0       NaN      0.000      0.849      0.151      0.4939
# 44975   155.0       NaN      0.000      0.651      0.349      0.8442
# 44979  1667.0       NaN      0.000      0.393      0.607      0.9667
